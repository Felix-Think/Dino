# %%
# !pip install albumentations pillow faiss-cpu tqdm transformers torch
# Out:
# Requirement already satisfied: albumentations in /venv/main/lib/python3.10/site-packages (2.0.6)
# Requirement already satisfied: pillow in /venv/main/lib/python3.10/site-packages (11.0.0)
# Requirement already satisfied: faiss-cpu in /venv/main/lib/python3.10/site-packages (1.11.0)
# Requirement already satisfied: tqdm in /venv/main/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: transformers in /venv/main/lib/python3.10/site-packages (4.51.3)
# Requirement already satisfied: torch in /venv/main/lib/python3.10/site-packages (2.6.0+cu124)
# Requirement already satisfied: scipy>=1.10.0 in /venv/main/lib/python3.10/site-packages (from albumentations) (1.15.2)
# Requirement already satisfied: pydantic>=2.9.2 in /venv/main/lib/python3.10/site-packages (from albumentations) (2.11.4)
# Requirement already satisfied: albucore==0.0.24 in /venv/main/lib/python3.10/site-packages (from albumentations) (0.0.24)
# Requirement already satisfied: numpy>=1.24.4 in /venv/main/lib/python3.10/site-packages (from albumentations) (2.1.2)
# Requirement already satisfied: PyYAML in /venv/main/lib/python3.10/site-packages (from albumentations) (6.0.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /venv/main/lib/python3.10/site-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: simsimd>=5.9.2 in /venv/main/lib/python3.10/site-packages (from albucore==0.0.24->albumentations) (6.2.1)
# Requirement already satisfied: stringzilla>=3.10.4 in /venv/main/lib/python3.10/site-packages (from albucore==0.0.24->albumentations) (3.12.5)
# Requirement already satisfied: packaging in /venv/main/lib/python3.10/site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: safetensors>=0.4.3 in /venv/main/lib/python3.10/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: filelock in /venv/main/lib/python3.10/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: requests in /venv/main/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /venv/main/lib/python3.10/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /venv/main/lib/python3.10/site-packages (from transformers) (0.30.2)
# Requirement already satisfied: regex!=2019.12.17 in /venv/main/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: triton==3.2.0 in /venv/main/lib/python3.10/site-packages (from torch) (3.2.0)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /venv/main/lib/python3.10/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /venv/main/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /venv/main/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /venv/main/lib/python3.10/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /venv/main/lib/python3.10/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: networkx in /venv/main/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /venv/main/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: jinja2 in /venv/main/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /venv/main/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /venv/main/lib/python3.10/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /venv/main/lib/python3.10/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /venv/main/lib/python3.10/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: fsspec in /venv/main/lib/python3.10/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: sympy==1.13.1 in /venv/main/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /venv/main/lib/python3.10/site-packages (from torch) (4.13.2)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /venv/main/lib/python3.10/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /venv/main/lib/python3.10/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /venv/main/lib/python3.10/site-packages (from torch) (2.21.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /venv/main/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /venv/main/lib/python3.10/site-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /venv/main/lib/python3.10/site-packages (from pydantic>=2.9.2->albumentations) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /venv/main/lib/python3.10/site-packages (from pydantic>=2.9.2->albumentations) (0.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /venv/main/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: idna<4,>=2.5 in /venv/main/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /venv/main/lib/python3.10/site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /venv/main/lib/python3.10/site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in /venv/main/lib/python3.10/site-packages (from requests->transformers) (3.4.1)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /venv/main/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /venv/main/lib/python3.10/site-packages (from scikit-learn) (2.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /venv/main/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /venv/main/lib/python3.10/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /venv/main/lib/python3.10/site-packages (from scikit-learn) (3.6.0)

# %%
import time
import cv2
import os
import numpy as np
import faiss
import torch
import pickle
import gc
import random
from tqdm import tqdm
from PIL import Image
from transformers import ViTModel, AutoImageProcessor
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
import albumentations as A








class DinoFaceRecognition:
    def __init__(self, src_dir=None):
        self.src_dir = src_dir
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

        self.model_name = "facebook/dino-vits8"
        self.model = ViTModel.from_pretrained(self.model_name).to(self.device)
        self.model.eval()
        self.processor = AutoImageProcessor.from_pretrained(self.model_name)

        self.index = None
        self.labels = []
        self.class_to_id = {}
        self.id_to_class = {}

        self.augmentor = A.Compose([
            A.Resize(128, 128, always_apply=True),
            A.RandomBrightnessContrast(brightness_limit=0.4, contrast_limit=0.4, p=1.0),
            A.CoarseDropout(min_holes=1, max_holes=1, min_height=20, max_height=30, min_width=40, max_width=50, fill_value=0, p=1.0),
            A.Rotate(limit=25, p=1.0)
        ])
    def augment_each_image(self, img):
        """
        Tăng cường 1 ảnh RGB (augmentor áp dụng).
        """
        if img is None or not isinstance(img, np.ndarray) or img.ndim != 3 or img.shape[2] != 3:
            return None
        return self.augmentor(image=img)['image']

    def augment_images(self, images):
        """
        Tạo tập ảnh gồm ảnh gốc và 40% ảnh augment.
    
        Args:
            images (List[np.ndarray]): Danh sách ảnh (BGR hoặc RGB).
    
        Returns:
            List[np.ndarray]: Ảnh gốc + ảnh augment.
        """
        if not isinstance(images, list) or len(images) == 0:
            return []
    
        # Đảm bảo ảnh là RGB
        rgb_images = []
        for img in images:
            if img is None:
                continue
            if isinstance(img, np.ndarray) and img.ndim == 3 and img.shape[2] == 3:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                rgb_images.append(img)
    
        # Augment 40%
        num_aug = max(1, int(len(rgb_images) * 0.4))
        selected_imgs = random.sample(rgb_images, num_aug)
        aug_images = [self.augment_each_image(img) for img in selected_imgs]
    
        return rgb_images + aug_images

    def load_data(self, faiss_index_path=None, metadata_path=None):
        if faiss_index_path and metadata_path:
            self.index = faiss.read_index(faiss_index_path)
            with open(metadata_path, 'rb') as f:
                metadata = pickle.load(f)
                self.labels = metadata['labels']
                self.class_to_id = metadata['label_to_id']
                self.id_to_class = {v: k for k, v in self.class_to_id.items()}



    def extract_features(self, images, normalize=True):
        try:
            if not isinstance(images, list):
                images = [images]
            valid_images = []
            for img in images:
                if img is None:
                    continue
                if isinstance(img, np.ndarray):
                    if len(img.shape) == 3 and img.shape[2] == 3:
                        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    else:
                        continue
                elif not isinstance(img, Image.Image):
                    continue
                valid_images.append(img)

            if not valid_images:
                return None

            inputs = self.processor(images=valid_images, return_tensors="pt").to(self.device)
            with torch.no_grad():
                outputs = self.model(**inputs)
                embeddings = outputs.last_hidden_state[:, 0, :].cpu().numpy()
            if normalize:
                embeddings = embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)
            return embeddings
        except:
            return None




    def recognize_face_topk(self, query_img, threshold=0.5, top_k=5):
        if query_img is None or query_img.size == 0:
            return [("Invalid Image", 0.0)]
        try:
            query_img = cv2.cvtColor(query_img, cv2.COLOR_BGR2RGB)
            query_embed = self.extract_features([query_img])
            if query_embed is None:
                return [("No Features Extracted", 0.0)]

            similarities, indices = self.index.search(query_embed.astype('float16'), k=top_k)

            votes = {}
            for i in range(top_k):
                pred_id = self.labels[indices[0][i]]
                label = self.id_to_class.get(pred_id, "Unknown")
                sim = float(similarities[0][i])
                if label not in votes:
                    votes[label] = []
                votes[label].append(sim)

            label_scores = {label: np.mean(sims) for label, sims in votes.items()}
            best_label = max(label_scores, key=label_scores.get)
            best_score = label_scores[best_label]

            if best_score >= threshold:
                return [(best_label, best_score)]
            else:
                return [("Unknown", best_score)]
        except Exception as e:
            print(f"[ERROR] in recognize_face_topk: {e}")
            return [("Error", 0.0)]


    def save_index(self, save_path):
        if self.index is not None and save_path:
            faiss.write_index(self.index, save_path + '.faiss')
            with open(f"{save_path}_metadata.pkl", "wb") as f:
                pickle.dump({
                    "labels": self.labels,
                    "label_to_id": self.class_to_id
                }, f)

    def train_in_batches(self, faiss_index_path=None, batch_size=5):
        if not self.src_dir:
            raise ValueError("Source directory (src_dir) not specified")
    
        self.labels = []
        all_class_names = sorted(os.listdir(self.src_dir))
        total_labels = len(all_class_names)
    
        for i in tqdm(range(0, total_labels, batch_size)):
            batch_class_names = all_class_names[i:i + batch_size]
            print(f"[Batch {i // batch_size + 1}] Training on classes: {batch_class_names} ({i + len(batch_class_names)} / {total_labels})")
    
            for class_name in batch_class_names:
                class_dir = os.path.join(self.src_dir, class_name)
                images = []
                if os.path.isdir(class_dir):
                    for img_name in os.listdir(class_dir):
                        img_path = os.path.join(class_dir, img_name)
                        if img_path.lower().endswith(('.png', '.jpg', '.jpeg')):
                            img = cv2.imread(img_path)
                            if img is None:
                                continue
                            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                            images.append(img)
    
                if not images:
                    continue
    
                # Gán label ID nếu chưa có
                if class_name not in self.class_to_id:
                    new_id = len(self.class_to_id)
                    self.class_to_id[class_name] = new_id
                    self.id_to_class[new_id] = class_name
                class_id = self.class_to_id[class_name]
    
                # Augment ảnh
                aug_images = self.augment_images(images)
                
                # Extract features
                feat_ori = self.extract_features(images)
                feat_aug = self.extract_features(aug_images)
    
                if feat_ori is None or feat_aug is None:
                    print(f"[SKIP] Feature extraction failed for class {class_name}")
                    continue
    
                # Tính vector trung bình
                mean_ori = np.mean(feat_ori, axis=0, keepdims=True)
                mean_aug = np.mean(feat_aug, axis=0, keepdims=True)
    
                # Gộp vectors: augment + mean_ori + mean_aug
                all_features = np.vstack([feat_aug, mean_ori, mean_aug])
                all_labels = [class_id] * all_features.shape[0]
                self.labels.extend(all_labels)
    
                # Tạo FAISS index nếu chưa có
                if self.index is None:
                    dim = all_features.shape[1]
                    self.index = faiss.IndexFlatL2(dim)
    
                # Thêm vào index
                self.index.add(all_features.astype('float32'))
    
                print(f"[INFO] Class {class_name}: {len(feat_aug)} augment vectors + 2 mean vectors added")
                print(f"[FAISS] Total vectors so far: {self.index.ntotal}")
    
            # ✅ Gọi hàm lưu chuẩn hoá
            self.save_index(faiss_index_path)
            gc.collect()
            torch.cuda.empty_cache()


    def recognize_face_topk(self, query_img, threshold=0.5, top_k=5):
        if query_img is None or query_img.size == 0:
            return [("Invalid Image", 0.0)]
        try:
            query_img = cv2.cvtColor(query_img, cv2.COLOR_BGR2RGB)
            query_embed = self.extract_features([query_img])
            if query_embed is None:
                return [("No Features Extracted", 0.0)]
    
            similarities, indices = self.index.search(query_embed.astype('float16'), k=top_k)
    
            votes = {}
            for i in range(top_k):
                pred_id = self.labels[indices[0][i]]
                label = self.id_to_class.get(pred_id, "Unknown")
                sim = float(similarities[0][i])
                if label not in votes:
                    votes[label] = []
                votes[label].append(sim)
    
            # Tính tổng điểm trung bình cho mỗi label
            label_scores = {label: np.mean(sims) for label, sims in votes.items()}
            best_label = max(label_scores, key=label_scores.get)
            best_score = label_scores[best_label]
    
            if best_score >= threshold:
                return [(best_label, best_score)]
            else:
                return [("Unknown", best_score)]
        except Exception as e:
            print(f"[ERROR] in recognize_face_topk: {e}")
            return [("Error", 0.0)]


    def print_faiss_size(self, faiss_file_path):
        if os.path.exists(faiss_file_path):
            size_in_bytes = os.path.getsize(faiss_file_path)
            size_in_mb = size_in_bytes / (1024 * 1024)
            print(f"[INFO] FAISS Index size: {size_in_mb:.2f} MB ({size_in_bytes} bytes)")
        else:
            print(f"[WARN] FAISS file not found: {faiss_file_path}")

    def evaluate_on_testset(self, test_dir, threshold=0.5, top_k=5):
        true_labels = []
        predicted_labels = []
        scores = []

        class_names = sorted(os.listdir(test_dir))
        for label in class_names:
            class_path = os.path.join(test_dir, label)
            if not os.path.isdir(class_path):
                continue
            for img_name in os.listdir(class_path):
                if img_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                    img_path = os.path.join(class_path, img_name)
                    img = cv2.imread(img_path)
                    if img is None:
                        continue
                    result = self.recognize_face_topk(img, threshold=threshold, top_k=top_k)[0]
                    pred_label, score = result
                    true_labels.append(label)
                    print(f'pred_label: {pred_label} | true_label: {label} | score: {score}')
                    predicted_labels.append(pred_label)
                    scores.append(score)

        acc = accuracy_score(true_labels, predicted_labels)
        f1 = f1_score(true_labels, predicted_labels, average='macro')

        label_list = sorted(set(true_labels + predicted_labels))
        label_to_idx = {label: idx for idx, label in enumerate(label_list)}
        y_true = [label_to_idx[l] for l in true_labels]
        y_score_matrix = np.zeros((len(scores), len(label_list)))
        for i, (pl, sc) in enumerate(zip(predicted_labels, scores)):
            if pl in label_to_idx:
                y_score_matrix[i][label_to_idx[pl]] = sc

        try:
            roc_auc = roc_auc_score(y_true, y_score_matrix, multi_class='ovr')
        except:
            roc_auc = "Cannot compute ROC AUC (possibly not enough classes)"

        return {
            "Accuracy": acc,
            "F1 Score (macro)": f1,
            "ROC AUC": roc_auc
        }

# %%
dino = DinoFaceRecognition(src_dir='train')
# 🆕 Train with augmentation
dino.train_in_batches(faiss_index_path = 'faiss_index', batch_size=1)
# Out:
# Some weights of ViTModel were not initialized from the model checkpoint at facebook/dino-vits8 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# /tmp/ipykernel_5992/260061141.py:39: UserWarning: Argument(s) 'always_apply' are not valid for transform Resize
#   A.Resize(128, 128, always_apply=True),
# /tmp/ipykernel_5992/260061141.py:41: UserWarning: Argument(s) 'min_holes, max_holes, min_height, max_height, min_width, max_width, fill_value' are not valid for transform CoarseDropout
#   A.CoarseDropout(min_holes=1, max_holes=1, min_height=20, max_height=30, min_width=40, max_width=50, fill_value=0, p=1.0),
#   0%|          | 1/962 [00:00<02:19,  6.87it/s]
# [Batch 1] Training on classes: ['.ipynb_checkpoints'] (1 / 962)
# [Batch 2] Training on classes: ['n000001'] (2 / 962)
#   0%|          | 2/962 [00:02<18:57,  1.18s/it]
# [INFO] Class n000001: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 142
# [Batch 3] Training on classes: ['n000009'] (3 / 962)
#   0%|          | 3/962 [00:04<24:48,  1.55s/it]
# [INFO] Class n000009: 175 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 319
# [Batch 4] Training on classes: ['n000011'] (4 / 962)
#   0%|          | 4/962 [00:05<24:30,  1.53s/it]
# [INFO] Class n000011: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 461
# [Batch 5] Training on classes: ['n000029'] (5 / 962)
#   1%|          | 5/962 [00:07<24:13,  1.52s/it]
# [INFO] Class n000029: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 603
# [Batch 6] Training on classes: ['n000040'] (6 / 962)
#   1%|          | 6/962 [00:09<27:16,  1.71s/it]
# [INFO] Class n000040: 196 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 801
# [Batch 7] Training on classes: ['n000065'] (7 / 962)
#   1%|          | 7/962 [00:10<26:14,  1.65s/it]
# [INFO] Class n000065: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 943
# [Batch 8] Training on classes: ['n000078'] (8 / 962)
#   1%|          | 8/962 [00:13<30:40,  1.93s/it]
# [INFO] Class n000078: 242 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 1187
# [Batch 9] Training on classes: ['n000082'] (9 / 962)
#   1%|          | 9/962 [00:15<33:39,  2.12s/it]
# [INFO] Class n000082: 254 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 1443
# [Batch 10] Training on classes: ['n000106'] (10 / 962)
#   1%|          | 10/962 [00:18<34:39,  2.18s/it]
# [INFO] Class n000106: 226 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 1671
# [Batch 11] Training on classes: ['n000129'] (11 / 962)
#   1%|          | 11/962 [00:19<31:24,  1.98s/it]
# [INFO] Class n000129: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 1813
# [Batch 12] Training on classes: ['n000136'] (12 / 962)
#   1%|          | 12/962 [00:21<28:45,  1.82s/it]
# [INFO] Class n000136: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 1955
# [Batch 13] Training on classes: ['n000148'] (13 / 962)
#   1%|▏         | 13/962 [00:23<32:38,  2.06s/it]
# [INFO] Class n000148: 239 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far:
 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 11066
# [Batch 75] Training on classes: ['n000912'] (75 / 962)
#   8%|▊         | 75/962 [01:58<21:50,  1.48s/it]
# [INFO] Class n000912: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 11208
# [Batch 76] Training on classes: ['n000920'] (76 / 962)
#   8%|▊         | 76/962 [02:00<22:20,  1.51s/it]
# [INFO] Class n000920: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 11350
# [Batch 77] Training on classes: ['n000928'] (77 / 962)
#   8%|▊         | 77/962 [02:01<21:51,  1.48s/it]
# [INFO] Class n000928: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 11492
# [Batch 78] Training on classes: ['n000945'] (78 / 962)
#   8%|▊         | 78/962 [02:03<21:32,  1.46s/it]
# [INFO] Class n000945: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 11634
# [Batch 79] Training on classes: ['n000950'] (79 / 962)
# [INFO] Class n000950: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 11776
#   8%|▊         | 79/962 [02:04<21:25,  1.46s/it]
# [Batch 80] Training on classes: ['n000958'] (80 / 962)
#   8%|▊         | 80/962 [02:06<21:44,  1.48s/it]
# [INFO] Class n000958: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 11918
# [Batch 81] Training on classes: ['n000977'] (81 / 962)
#   8%|▊         | 81/962 [02:07<22:22,  1.52s/it]
# [INFO] Class n000977: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 12060
# [Batch 82] Training on classes: ['n000998'] (82 / 962)
#   9%|▊         | 82/962 [02:09<21:54,  1.49s/it]
# [INFO] Class n000998: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 12202
# [Batch 83] Training on classes: ['n001021'] (83 / 962)
#   9%|▊         | 83/962 [02:10<22:02,  1.50s/it]
# [INFO] Class n001021: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 12344
# [Batch 84] Training on classes: ['n001041'] (84 / 962)
#   9%|▊         | 84/962 [02:12<22:10,  1.52s/it]
# [INFO] Class n001041: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 12486
# [Batch 85] Training on classes: ['n001046'] (85 / 962)
#   9%|▉         | 85/962 [02:13<22:11,  1.52s/it]
# [INFO] Class n001046: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 12628
# [Batch 86] Training on classes: ['n001048'] (86 / 962)
#   9%|▉         | 86/962 [02:15<22:19,  1.53s/it]
# [INFO] Class n001048: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 12770
# [Batch 87] Training on classes: ['n001059'] (87 / 962)
# [INFO] Class n001059: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 12912
#   9%|▉         | 87/962 [02:16<21:57,  1.51s/it]
# [Batch 88] Training on classes: ['n001069'] (88 / 962)
#   9%|▉         | 88/962 [02:18<22:46,  1.56s/it]
# [INFO] Class n001069: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 13054
# [Batch 89] Training on classes: ['n001103'] (89 / 962)
# [INFO] Class n001103: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 13196
#   9%|▉         | 89/962 [02:20<22:50,  1.57s/it]
# [Batch 90] Training on classes: ['n001125'] (90 / 962)
#   9%|▉         | 90/962 [02:21<22:19,  1.54s/it]
# [INFO] Class n001125: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 13338
# [Batch 91] Training on classes: ['n001127'] (91 / 962)
#   9%|▉         | 91/962 [02:23<22:17,  1.54s/it]
# [INFO] Class n001127: 140 augment vectors + 2 mean vectors added
# [FAISS] Total vectors so far: 13480
# [Batch 92] Training on classes: ['n001145'] (92 / 962)

# %%
dino.load_data('faiss_index.faiss', 'faiss_index_metadata.pkl')

# %%
dino.print_faiss_size('faiss_index.faiss')
#|%%--%%| <AGMxKnSMeM|mJYsVXolyl>
if dino.index is not None:
    print(f"[INFO] FAISS Index contains {dino.index.ntotal} vectors.")
else:
    print("[WARN] FAISS index not initialized.")

# %%
results = dino.evaluate_on_testset(test_dir='test')
print(results)
